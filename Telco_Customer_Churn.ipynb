# %%
import pandas as pd  
import matplotlib.pyplot as plt

# %%
# load the dataset
df=pd.read_csv('Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# to count rows and columns 
df.shape
# Out:
# (7043, 21)

# %%
# column name and data type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# any missing value 
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# distribution of churn column
df['Churn'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Churn'>

# %%
# unique value 
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
# average monthly charges of customer 
df['MonthlyCharges'].mean()
# Out:
# np.float64(64.76169246059918)

# %%
# top 5 most common internet services types
df['InternetService'].value_counts().head()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
# distribution of tenure using histogram 
df['tenure'].plot(kind='hist',bins=5,title='Distribution of Tenure',color='skyblue')
plt.xlabel('tenure')
plt.show()

# %%
# how contract type affected churn
pd.crosstab(df['Contract'],df['Churn']).plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Contract'>

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# how many customers have Phone Services 
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
# Compare MonthlyCharges for customers with and without StreamingTV.
df.groupby('StreamingTV')['MonthlyCharges'].mean()
# Out:
# StreamingTV
# No                     65.387687
# No internet service    21.079194
# Yes                    88.736738
# Name: MonthlyCharges, dtype: float64

# %%
# gender highest churn rate
df.groupby('gender')['Churn'].idxmax()
# Out:
# gender
# Female    4
# Male      2
# Name: Churn, dtype: int64

# %%
# Find the average TotalCharges grouped by SeniorCitizen
df.groupby('SeniorCitizen')['MonthlyCharges'].mean()
# Out:
# SeniorCitizen
# 0    61.847441
# 1    79.820359
# Name: MonthlyCharges, dtype: float64

# %%
# Tenure vs Total Charges scatter plot
df.plot.scatter(x='tenure',y='MonthlyCharges')
plt.show()

# %%
# descriptive stats for numerical columns 
df[['tenure','MonthlyCharges','TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
# churn rate by contract type 
df.groupby('Contract')['Churn'].value_counts(normalize=True)*100
# Out:
# Contract        Churn
# Month-to-month  No       57.290323
#                 Yes      42.709677
# One year        No       88.730482
#                 Yes      11.269518
# Two year        No       97.168142
#                 Yes       2.831858
# Name: proportion, dtype: float64

# %%
# payment method with highest churn
df[df['Churn']=='Yes']['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             1071
# Mailed check                  308
# Bank transfer (automatic)     258
# Credit card (automatic)       232
# Name: count, dtype: int64

# %%
# top 10 by monthly charges 
df.sort_values(by='MonthlyCharges',ascending=False).head(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4586  7569-NMZYQ  Female              0     Yes        Yes      72
# 2115  8984-HPEMB  Female              0      No         No      71
# 4804  5734-EJKXG  Female              0      No         No      61
# 3894  5989-AXPUC  Female              0     Yes         No      68
# 5127  8199-ZLLSA    Male              0      No         No      67
# 6118  9924-JPRMC    Male              0      No         No      72
# 4610  2889-FPWRM    Male              0     Yes         No      72
# 3205  3810-DVDQQ  Female              0     Yes        Yes      72
# 6768  9739-JLPQJ  Female              0     Yes        Yes      72
# 4875  2302-ANTDP  Female              1     Yes         No      48
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4586          Yes           Yes     Fiber optic            Yes  ...
# 2115          Yes           Yes     Fiber optic            Yes  ...
# ...

# %%
# Customers with 0 tenure and churned
df[(['tenure']==0) & (df['Churn']=='Yes')]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
# No InternetService but MonthlyCharges > 80
df[(['InternetService']=='No') & (df['MonthlyCharges']>80)]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Sort by TotalCharges descending
df.sort_values(by='TotalCharges',ascending=False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2845  9093-FPDLG  Female              0      No         No      11
# 3353  4536-PLEQY    Male              0     Yes         No      12
# 3686  5899-MQZZL  Female              0      No         No      13
# 5598  6051-PTVNS  Female              0     Yes        Yes      55
# 6646  8249-THVEC    Male              0     Yes        Yes      51
# ...          ...     ...            ...     ...        ...     ...
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2845          Yes                No     Fiber optic                   No  ...
# ...

# %%
# Crosstab of gender vs. churn
pd.crosstab(df['gender'],df['Churn'])
# Out:
# Churn     No  Yes
# gender
# Female  2549  939
# Male    2625  930

# %%
# TechSupport usage by gender
pd.crosstab(df['gender'],df['TechSupport'])
# Out:
# TechSupport    No  No internet service   Yes
# gender
# Female       1714                  747  1027
# Male         1759                  779  1017

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df['TotalCharges'].mean()
# Out:
# np.float64(2283.3004408418656)

# %%
# final 
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
